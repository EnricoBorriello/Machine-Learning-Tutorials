# %% [markdown]
# # ML 03 - Logistic Regression, part 1 (warm-up)
#
# This time we cannot derive an analytical solution to test our numerical algorithm. Therefore, we test our classifier on a simple data set with only two features that we can easily visualize.
#
# - **Author:** Enrico Borriello
# - **Contact:** enrico.borriello@asu.edu
# - Sept 2018

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %% [markdown]
# ## Dataset
#
# Import the sample data **``warm-up_logreg_data.csv``**

# %%
df = pd.read_csv('warm-up_logreg_data.csv',names=['feature 1','feature 2','class'])

# %%
# visualize the initial rows
df[:5]
# Out:
#    feature 1  feature 2  class
# 0  -0.366641  -0.253435      0
# 1  -0.054441  -0.391336      0
# 2  -0.606181   0.551683      1
# 3   0.484166  -0.383942      0
# 4   0.387543  -0.631888      0

# %%
x1 = np.array(df['feature 1'])
x2 = np.array(df['feature 2'])
Y = np.array(df['class'])

# %%
colors = ['gray','orange']
fig = plt.figure(figsize=(6,6))
plt.scatter(x1, x2, c=Y, cmap=matplotlib.colors.ListedColormap(colors))
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.xlabel('feature 1',size = 12)
plt.ylabel('feature 2',size = 12)
plt.legend();

# %% [markdown]
# ## Assignment
# Develop a logistic regression algorithm for the binary classification of the labeled data $\{(x_1^{(t)},x_2^{(t)},y^{(t)})\}_{t=1,\dots,m}$. To visualize the result, draw a **decision boundary** at $50\%$, i.e. the contour of the region of the $(x_1,x_2)$ plane where $p(y=1\,|\,x_1,x_2)\geq50\%$.
